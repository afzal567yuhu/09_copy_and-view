# %%
import numpy as np

# %% [markdown]
# COPY AND VIEW

# %%
var = np.array([4,5,2,6])
co = var.copy()
print ("copy:",co)
# Out:
# copy: [4 5 2 6]

# %%
x = np.array([8,5,4,6,2,4,6,2])
v = x.view()
print("view:",v)
# Out:
# view: [8 5 4 6 2 4 6 2]
